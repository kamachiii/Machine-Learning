# %%
import pandas as pd

# Daftar kolom yang ingin Anda ambil
kolom_pilihan = ['instant', 'dteday', 'session', 'temp', 'hum', 'windspeed']

# Membaca seluruh data ke df (seperti yang Anda lakukan)
df = pd.read_csv('../data/day.csv', sep=',')

# HANYA membaca kolom yang Anda inginkan ke df1
df1 = pd.read_csv('../data/day.csv', sep=',', usecols=kolom_pilihan)

print("--- df (Semua Kolom) ---")
df.head()

print("\n--- df1 (Kolom Pilihan) ---")
df1.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 10
#       4 kolom_pilihan = ['instant', 'dteday', 'session', 'temp', 'hum', 'windspeed']
#       6 # Membaca seluruh data ke df (seperti yang Anda lakukan)
#       7 #df = pd.read_csv('../data/day.csv', sep=',')
#       8
#       9 # HANYA membaca kolom yang Anda inginkan ke df1
# ---> 10 df1 = pd.read_csv('../data/day.csv', sep=',', usecols=kolom_pilihan)
#      12 print("--- df (Semua Kolom) ---")
#      13 #df.head()
#      14
#      15 #print("\n--- df1 (Kolom Pilihan) ---")
#
# ...
